# %% [markdown]
# Manipulation de formats semi-structurés (JSON & Excel)

# %%
import pandas as pd

df_movies = pd.read_json("../data/movies.json")

df_movies.head()
# Out:
#                                   title  year cast    genres  \
# 0            After Dark in Central Park  1900   []        []
# 1  Boarding School Girls' Pajama Parade  1900   []        []
# 2        Buffalo Bill's Wild West Parad  1900   []        []
# 3                                Caught  1900   []        []
# 4                  Clowns Spinning Hats  1900   []  [Silent]
#
#                    href                                            extract  \
# 0                  None                                                NaN
# 1                  None                                                NaN
# 2                  None                                                NaN
# 3                  None                                                NaN
# 4  Clowns_Spinning_Hats  Clowns Spinning Hats is a black-and-white sile...
#
#   thumbnail  thumbnail_width  thumbnail_height
# 0       NaN              NaN               NaN
# 1       NaN              NaN               NaN
# ...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36273 entries, 0 to 36272
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             36273 non-null  object
#  1   year              36273 non-null  int64
#  2   cast              36273 non-null  object
#  3   genres            36273 non-null  object
#  4   href              34540 non-null  object
#  5   extract           34532 non-null  object
#  6   thumbnail         30368 non-null  object
#  7   thumbnail_width   30368 non-null  float64
#  8   thumbnail_height  30368 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 2.5+ MB

# %% [markdown]
# Si le fichier est au format "JSON Lines", quel argument devez-vous ajouter ?
# Il faut ajouter l'argument lines=True, ce qui donne :
#
# pd.read_json('fichier.json', lines=True).

# %% [markdown]
# Données de Gestion (Excel)

# %%
import pandas as pd
df_excel = pd.read_excel("../data/Financial Sample.xlsx")
df_excel.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera           NaN      1618.5
# 1  Government  Germany  Carretera           NaN      1321.0
# 2   Midmarket   France  Carretera           NaN      2178.0
# 3   Midmarket  Germany  Carretera           NaN       888.0
# 4   Midmarket   Mexico  Carretera           NaN      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...
